# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wc-at.csv')

# %%
df.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
meanofwaist = df['Waist'].mean()

# %%
meanofwaist
# Out:
# 91.90183486238531

# %%
medianofwaist = df['Waist'].median()

# %%
medianofwaist
# Out:
# 90.8

# %%
medianofat = df['AT'].median()
medianofat
# Out:
# 96.54

# %%
meanofat = df['AT'].mean()

# %%
meanofat
# Out:
# 101.89403669724771

# %%
df['Waist'].hist()
# Out:
# <Axes: >

# %%
sns.distplot(df['Waist'])
plt.show()
# Out:
# C:\Users\Rathnavel\AppData\Local\Temp\ipykernel_20620\3477598312.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Waist'])

# %%
#mean>median, it is a positive skewness

# %%
sns.distplot(df['AT'])
plt.show()
# Out:
# C:\Users\Rathnavel\AppData\Local\Temp\ipykernel_20620\2611756453.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['AT'])

# %%
#mean>median, it is a positive skewness
